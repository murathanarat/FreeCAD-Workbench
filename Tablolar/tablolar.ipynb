# %%
import pandas as pd

# %%
a = pd.read_csv(r"C:\Users\murat\Desktop\Ahsap Hesap Program\Program\Tablolar\tablo1.4.txt",header=0,sep=";")

# %%
a[a["Nem Durumu"] == "Az"]
# Out:
#   Nem Durumu  Nem Durumu Düzeltme Katsayısı,Cn  \
# 0         Az                               1.0
#
#                               Açıklama
# 0  Ahşabın nem içeriği %12'den az(KS1)

# %%
def Cn(nem_durumu):
    
    pass

# %%
def Cy():
    pass

# %%
def Gd(Gort,omega):
    return Gort/omega

# %%
def Ed(Eort,omega):
    return Eort/omega

# %%
def Xd(Cn,Cy,Xk,omega):
    return (Cn*Cy)
